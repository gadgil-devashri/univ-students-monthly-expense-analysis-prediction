# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv('data/University Students Monthly Expenses.csv')

# %%
df = df[df.isnull().sum(axis=1) < 3]
df = df.drop_duplicates()

# %%
df
# Out:
#      Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 0   Female    21         2.0    Home          No            No           No
# 1     Male    25         3.0  Hostel          No           Yes   Motorcycle
# 2     Male    23         2.0    Home         Yes            No           No
# 3     Male    19         3.0  Hostel          No            No   Motorcycle
# 4   Female    19         2.0    Home          No            No   Motorcycle
# 5     Male    22         3.0  Hostel          No           Yes          Car
# 6   Female    21         2.0    Home         Yes            No           No
# 7     Male    22         3.0  Hostel          No           Yes   Motorcycle
# 8   Female    18         1.0    Home         Yes            No           No
# 9     Male    19         1.0    Home          No            No           No
# 10    Male    22         3.0    Home          No            No          Car
# 11    Male    18         2.0  Hostel          No            No   Motorcycle
# 12  Female    18         2.0    Home          No            No           No
# 14  Female    22         4.0  Hostel         Yes           Yes          Car
# 15    Male    22         4.0    Home          No            No          Car
# 16  Female    17         1.0    Home          No            No          Car
# 17  Female    19         2.0  Hostel          No           NaN          NaN
# 18  Female    23         4.0    Home          No            No           No
# 19  Female    19         3.0    Home          No            No   Motorcycle
# 20    Male    19         2.0  Hostel          No           Yes          Car
# 21  Female    22         4.0    Home         Yes           Yes          Car
# 22    Male    21         4.0    Home          No            No          Car
# 23  Female    22         4.0    Home          No           Yes           No
# 24    Male    18         2.0    Home          No            No   Motorcycle
# 25  Female    19         NaN  Hostel          No            No           No
# 26    Male    22         4.0    Home         Yes            No           No
# 27    Male    18         1.0    Home         Yes            No           No
# 28    Male    18         1.0  Hostel         Yes            No   Motorcycle
# 29  Female    19         2.0    Home          No            No           No
# 30    Male    22         3.0    Home          No           Yes          NaN
# 31  Female    19         2.0  Hostel         Yes           Yes          Car
# 32    Male    23         4.0    Home          No           NaN          Car
# 33  Female    19         3.0    Home          No            No   Motorcycle
# 34  Female    19         2.0     NaN         Yes            No          NaN
# 35    Male    22         4.0  Hostel          No            No           No
# 36  Female    21         4.0    Home          No           Yes   Motorcycle
# 37    Male    22         NaN  Hostel         Yes           Yes          Car
# 38  Female    18         2.0    Home          No            No          Car
# 39    Male    19         2.0    Home          No            No          Car
# 43  Female    18         2.0    Home          No            No   Motorcycle
# 57    Male    22         4.0    Home         Yes            No   Motorcycle
# 59  Female    19         3.0    Home          No            No          Car
#
#    Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 0       No     No              No                   Yes                   No
# 1       No     No             Yes                   Yes                  Yes
# 2       No     No              No                    No                  NaN
# 3       No     No             Yes                   Yes                  Yes
# 4       No     No              No                   Yes                   No
# 5      NaN    Yes             Yes                    No                   No
# 6       No     No             Yes                    No                  Yes
# 7      Yes     No             Yes                   NaN                  Yes
# 8       No     No              No                   Yes                  Yes
# 9      NaN     No             Yes                   Yes                  NaN
# 10      No     No              No                   Yes                  Yes
# 11      No     No             Yes                    No                   No
# 12      No     No             Yes                   Yes                   No
# 14      No     No              No                   Yes                  Yes
# 15      No     No             Yes                    No                   No
# 16      No     No              No                    No                   No
# 17      No     No             Yes                   Yes                   No
# 18      No    NaN             Yes                   Yes                  Yes
# 19      No     No             Yes                   Yes                  Yes
# 20     NaN     No             Yes                   NaN                  Yes
# 21     Yes     No             Yes                   Yes                   No
# 22     Yes     No              No                    No                   No
# 23      No     No             Yes                    No                  Yes
# 24      No     No              No                    No                  Yes
# 25     NaN     No             Yes                   Yes                  Yes
# 26     Yes    Yes             Yes                    No                  Yes
# 27      No     No             Yes                    No                  Yes
# 28      No     No              No                    No                   No
# 29      No     No             Yes                    No                   No
# 30     Yes    Yes              No                    No                   No
# 31      No     No             Yes                   Yes                  Yes
# 32     Yes     No             Yes                   NaN                   No
# 33      No     No             Yes                   Yes                   No
# 34      No     No              No                   Yes                   No
# 35     Yes    NaN             Yes                    No                  Yes
# 36     NaN     No              No                   Yes                  NaN
# 37      No    NaN             Yes                    No                  Yes
# 38     Yes     No             Yes                   Yes                   No
# 39     Yes    Yes             Yes                    No                   No
# 43      No     No             Yes                   Yes                   No
# 57     Yes    Yes             Yes                    No                  Yes
# 59      No     No             Yes                   Yes                   No
#
#     Monthly_expenses_$
# 0                150.0
# 1                220.0
# 2                180.0
# 3                200.0
# 4                300.0
# 5                150.0
# 6                200.0
# 7                200.0
# 8                150.0
# 9                160.0
# 10               350.0
# 11               180.0
# 12               140.0
# 14               300.0
# 15               250.0
# 16               250.0
# 17               150.0
# 18               150.0
# 19               200.0
# 20               300.0
# 21               200.0
# 22               150.0
# 23               220.0
# 24               180.0
# 25               200.0
# 26               300.0
# 27               150.0
# 28               200.0
# 29               200.0
# 30               150.0
# 31                 NaN
# 32               350.0
# 33               170.0
# 34               180.0
# 35               200.0
# 36               300.0
# 37               250.0
# 38               300.0
# 39               250.0
# 43               140.0
# 57               300.0
# 59               170.0

# %%
df = df[df['Monthly_expenses_$'].notna()]
# Out:
# Gender                   53
# Age                      53
# Study_year               51
# Living                   53
# Scholarship              53
# Part_time_job            50
# Transporting             50
# Smoking                  49
# Drinks                   48
# Games_&_Hobbies          53
# Cosmetics_&_Self-care    51
# Monthly_Subscription     50
# Monthly_expenses_$       53
# dtype: int64

# %%
df[df.isnull().sum(axis=1) > 0]
# Out:
#       Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 2      Male    23         2.0    Home         Yes            No           No
# 5      Male    22         3.0  Hostel          No           Yes          Car
# 7      Male    22         3.0  Hostel          No           Yes   Motorcycle
# 9      Male    19         1.0    Home          No            No           No
# 17   Female    19         2.0  Hostel          No           NaN          NaN
# 18   Female    23         4.0    Home          No            No           No
# 20     Male    19         2.0  Hostel          No           Yes          Car
# 25   Female    19         NaN  Hostel          No            No           No
# 30     Male    22         3.0    Home          No           Yes          NaN
# 32     Male    23         4.0    Home          No           NaN          Car
# 34   Female    19         2.0     NaN         Yes            No          NaN
# 35     Male    22         4.0  Hostel          No            No           No
# 36   Female    21         4.0    Home          No           Yes   Motorcycle
# 37     Male    22         NaN  Hostel         Yes           Yes          Car
# 48   Female    19         2.0  Hostel          No           NaN          NaN
# 49   Female    23         4.0    Home          No            No           No
# 56   Female    19         NaN  Hostel          No            No           No
# 61     Male    22         4.0  Hostel          No            No           No
# 62   Female    21         4.0    Home          No           Yes   Motorcycle
# 63     Male    22         NaN  Hostel         Yes           Yes          Car
# 74   Female    19         2.0  Hostel          No           NaN          NaN
# 75   Female    23         4.0    Home          No            No           No
# 77     Male    23         2.0    Home         Yes            No           No
# 80     Male    22         3.0  Hostel          No           Yes          Car
# 82     Male    22         3.0  Hostel          No           Yes   Motorcycle
# 96   Female    19         2.0  Hostel          No           NaN          NaN
# 97   Female    23         4.0    Home          No            No           No
# 99     Male    23         2.0    Home         Yes            No           No
# 102    Male    22         3.0  Hostel          No           Yes          Car
# 104    Male    22         3.0  Hostel          No           Yes   Motorcycle
#
#     Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 2        No     No              No                    No                  NaN
# 5       NaN    Yes             Yes                    No                   No
# 7       Yes     No             Yes                   NaN                  Yes
# 9       NaN     No             Yes                   Yes                  NaN
# 17       No     No             Yes                   Yes                   No
# 18       No    NaN             Yes                   Yes                  Yes
# 20      NaN     No             Yes                   NaN                  Yes
# 25      NaN     No             Yes                   Yes                  Yes
# 30      Yes    Yes              No                    No                   No
# 32      Yes     No             Yes                   NaN                   No
# 34       No     No              No                   Yes                   No
# 35      Yes    NaN             Yes                    No                  Yes
# 36      NaN     No              No                   Yes                  NaN
# 37       No    NaN             Yes                    No                  Yes
# 48       No     No             Yes                   Yes                   No
# 49       No    NaN             Yes                   Yes                  Yes
# 56      NaN     No             Yes                   Yes                  Yes
# 61      Yes    NaN             Yes                    No                  Yes
# 62      NaN     No              No                   Yes                  NaN
# 63       No    NaN             Yes                    No                  Yes
# 74       No     No             Yes                   Yes                   No
# 75       No    NaN             Yes                   Yes                  Yes
# 77       No     No              No                    No                  NaN
# 80      NaN    Yes             Yes                    No                   No
# 82      Yes     No             Yes                   NaN                  Yes
# 96       No     No             Yes                   Yes                   No
# 97       No    NaN             Yes                   Yes                  Yes
# 99       No     No              No                    No                  NaN
# 102     NaN    Yes             Yes                    No                   No
# 104     Yes     No             Yes                   NaN                  Yes
#
#      Monthly_expenses_$
# 2                 180.0
# 5                 150.0
# 7                 200.0
# 9                 160.0
# 17                150.0
# 18                150.0
# 20                300.0
# 25                200.0
# 30                150.0
# 32                350.0
# 34                180.0
# 35                200.0
# 36                300.0
# 37                250.0
# 48                150.0
# 49                150.0
# 56                200.0
# 61                200.0
# 62                300.0
# 63                250.0
# 74                150.0
# 75                150.0
# 77                180.0
# 80                150.0
# 82                200.0
# 96                150.0
# 97                150.0
# 99                180.0
# 102               150.0
# 104               200.0
