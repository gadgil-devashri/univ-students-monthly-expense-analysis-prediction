# %%
# Data exploration - expense dataset

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/University Students Monthly Expenses.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 105 non-null    object
#  1   Age                    105 non-null    int64
#  2   Study_year             101 non-null    float64
#  3   Living                 103 non-null    object
#  4   Scholarship            105 non-null    object
#  5   Part_time_job          100 non-null    object
#  6   Transporting           91 non-null     object
#  7   Smoking                94 non-null     object
#  8   Drinks                 92 non-null     object
#  9   Games_&_Hobbies        105 non-null    object
#  10  Cosmetics_&_Self-care  92 non-null     object
#  11  Monthly_Subscription   96 non-null     object
#  12  Monthly_expenses_$     99 non-null     float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 10.8+ KB

# %%
for c in df.columns:
    print(df[c].unique())
# Out:
# ['Female ' 'Male ']
# [21 25 23 19 22 18 17]
# [ 2.  3.  1.  4. nan]
# ['Home' 'Hostel' nan]
# ['No' 'Yes']
# ['No' 'Yes' nan]
# ['No' 'Motorcycle' 'Car' nan]
# ['No' nan 'Yes']
# ['No' 'Yes' nan]
# ['No' 'Yes']
# ['Yes' 'No' nan]
# ['No' 'Yes' nan]
# [150. 220. 180. 200. 300. 160. 350. 140.  nan 250. 170. 280. 230.]

# %%
# Categorical: Gender, Living, Scholarship, Part_time_job, Transporting, Smoking, Drinks, Games_&_Hobbies, Cosmetics_&_Self-care, Monthly_Subscription
# Ordinal - Age, Study_year
# Quantitative - Monthly_expenses_$

# %%
df = df[df.isnull().sum(axis=1) < 3]

# %%
df[df.isnull().sum(axis=1) > 1]
# Out:
#      Gender  Age  Study_year  Living Scholarship Part_time_job Transporting  \
# 9     Male    19         1.0    Home          No            No           No
# 17  Female    19         2.0  Hostel          No           NaN          NaN
# 20    Male    19         2.0  Hostel          No           Yes          Car
# 25  Female    19         NaN  Hostel          No            No           No
# 32    Male    23         4.0    Home          No           NaN          Car
# 34  Female    19         2.0     NaN         Yes            No          NaN
# 36  Female    21         4.0    Home          No           Yes   Motorcycle
# 37    Male    22         NaN  Hostel         Yes           Yes          Car
# 48  Female    19         2.0  Hostel          No           NaN          NaN
# 56  Female    19         NaN  Hostel          No            No           No
# 62  Female    21         4.0    Home          No           Yes   Motorcycle
# 63    Male    22         NaN  Hostel         Yes           Yes          Car
# 74  Female    19         2.0  Hostel          No           NaN          NaN
# 96  Female    19         2.0  Hostel          No           NaN          NaN
#
#    Smoking Drinks Games_&_Hobbies Cosmetics_&_Self-care Monthly_Subscription  \
# 9      NaN     No             Yes                   Yes                  NaN
# 17      No     No             Yes                   Yes                   No
# 20     NaN     No             Yes                   NaN                  Yes
# 25     NaN     No             Yes                   Yes                  Yes
# 32     Yes     No             Yes                   NaN                   No
# 34      No     No              No                   Yes                   No
# 36     NaN     No              No                   Yes                  NaN
# 37      No    NaN             Yes                    No                  Yes
# 48      No     No             Yes                   Yes                   No
# 56     NaN     No             Yes                   Yes                  Yes
# 62     NaN     No              No                   Yes                  NaN
# 63      No    NaN             Yes                    No                  Yes
# 74      No     No             Yes                   Yes                   No
# 96      No     No             Yes                   Yes                   No
#
#     Monthly_expenses_$
# 9                160.0
# 17               150.0
# 20               300.0
# 25               200.0
# 32               350.0
# 34               180.0
# 36               300.0
# 37               250.0
# 48               150.0
# 56               200.0
# 62               300.0
# 63               250.0
# 74               150.0
# 96               150.0
